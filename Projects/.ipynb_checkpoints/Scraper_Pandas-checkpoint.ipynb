# %%
import pandas as pd
import lxml

# %%
scraper = pd.read_html("https://en.wikipedia.org/wiki/Kylian_Mbappe")

# %%
for idx, table in enumerate (scraper):
    print("********************************************************")
    print(idx)
    print(table)
# Out:
# ********************************************************
# 0
#                                                     0  \
# 0             Mbappé with Paris Saint-Germain in 2019
# 1                                Personal information
# 2                                           Full name
# 3                                       Date of birth
# 4                                      Place of birth
# 5                                              Height
# 6                                         Position(s)
# 7                                    Team information
# 8                                        Current team
# 9                                              Number
# 10                                       Youth career
# 11                                          2004–2013
# 12                                          2013–2015
# 13                                     Senior career*
# 14                                              Years
# ...

# %%
scraper[2]
# Out:
#                           Club        Season        League             \
#                           Club        Season      Division Apps Goals
# 0                    Monaco II       2015–16           CFA   10     2
# 1                    Monaco II       2016–17           CFA    2     2
# 2                    Monaco II         Total         Total   12     4
# 3                       Monaco       2015–16       Ligue 1   11     1
# 4                       Monaco       2016–17       Ligue 1   29    15
# 5                       Monaco       2017–18       Ligue 1    1     0
# 6                       Monaco         Total         Total   41    16
# 7   Paris Saint-Germain (loan)       2017–18       Ligue 1   27    13
# 8          Paris Saint-Germain       2018–19       Ligue 1   29    33
# 9          Paris Saint-Germain       2019–20       Ligue 1   20    18
# 10         Paris Saint-Germain       2020–21       Ligue 1   31    27
# ...
